# %% [markdown]
# ## IMPORT PANDAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("Transactions_dataset.csv")

# %% [markdown]
# ## Using Head show the first 5 rows in default

# %%
print(df.head())
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  2002-10-20               35.47
# 1        26381  Michelle     Phelps    NaN  1985-10-24             2552.72
# 2       305449     Jacob   Williams      M  1981-10-25              115.97
# 3       988259    Nathan     Snyder      M  1977-10-26               11.31
# 4       764762   Crystal      Knapp      F  1951-11-02               62.21
#
#          Date               Merchant Name     Category
# 0  2023-04-03               Smith-Russell     Cosmetic
# 1  2023-07-17      Peck, Spence and Young       Travel
# 2  2023-09-20                  Steele Inc     Clothing
# 3  2023-01-11  Wilson, Wilson and Russell     Cosmetic
# 4  2023-06-13               Palmer-Hinton  Electronics

# %% [markdown]
# ## Using Tail Shows the last 5 rows in default

# %%
print(df.tail())
# Out:
#        Customer ID       Name   Surname Gender   Birthdate  \
# 49995       891845  Christine     Leach      F  1997-10-21
# 49996       800560       Anna     Allen      F  1999-10-21
# 49997       133285     Nicole  Franklin      M  1979-10-26
# 49998       616122      Maria    Keller      M  1981-10-25
# 49999       832184      Billy    Walker      F  1958-10-31
#
#        Transaction Amount        Date                 Merchant Name  Category
# 49995              108.74  2023-08-30                 Alexander Ltd    Market
# 49996              133.66  2023-05-03                 Knapp-Calhoun  Cosmetic
# 49997              464.29  2023-02-12  Cantrell, Haynes and Ballard    Market
# 49998              472.57  2023-03-25     Wilson, Jackson and Beard    Market
# 49999              270.67  2023-05-20                     Combs LLC    Market

# %% [markdown]
# ## Using info is a Quick Summery in Dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44953 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         44953 non-null  int64
#  1   Name                44953 non-null  object
#  2   Surname             44953 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           44953 non-null  object
#  5   Transaction Amount  44953 non-null  float64
#  6   Date                44953 non-null  datetime64[ns]
#  7   Merchant Name       44953 non-null  object
#  8   Category            44953 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 3.4+ MB
# None

# %% [markdown]
# ## Describe the Statistics

# %%
print(df.describe())
# Out:
#          Customer ID  Transaction Amount                           Date
# count   44953.000000        44953.000000                          44953
# mean   500291.017307          442.996086  2023-05-23 14:20:28.963584256
# min        29.000000            5.010000            2023-01-01 00:00:00
# 25%    251207.000000           79.200000            2023-03-13 00:00:00
# 50%    499534.000000          182.360000            2023-05-24 00:00:00
# 75%    749999.000000          471.820000            2023-08-03 00:00:00
# max    999997.000000         2999.880000            2023-10-14 00:00:00
# std    288276.249030          632.486149                            NaN

# %% [markdown]
# ## Using Mean

# %%
df.mean(numeric_only = True)
# Out:
# Customer ID           500291.017307
# Transaction Amount       442.996086
# dtype: float64

# %% [markdown]
# ## Using Median

# %%
df.median(numeric_only = True)
# Out:
# Customer ID           499520.500
# Transaction Amount       182.195
# dtype: float64

# %% [markdown]
# ## Using Mode

# %%
df.mode()
# Out:
#        Customer ID     Name Surname Gender   Birthdate  Transaction Amount  \
# 0               29  Michael   Smith      F  1954-11-01               68.89
# 1               51      NaN     NaN    NaN         NaN                 NaN
# 2               54      NaN     NaN    NaN         NaN                 NaN
# 3               83      NaN     NaN    NaN         NaN                 NaN
# 4               90      NaN     NaN    NaN         NaN                 NaN
# ...            ...      ...     ...    ...         ...                 ...
# 49995       999904      NaN     NaN    NaN         NaN                 NaN
# 49996       999914      NaN     NaN    NaN         NaN                 NaN
# 49997       999942      NaN     NaN    NaN         NaN                 NaN
# 49998       999949      NaN     NaN    NaN         NaN                 NaN
# 49999       999997      NaN     NaN    NaN         NaN                 NaN
#
#              Date Merchant Name    Category
# ...

# %% [markdown]
# ## Find Null Values

# %%
print(df.isnull().sum())
# Out:
# Customer ID           0
# Name                  0
# Surname               0
# Gender                0
# Birthdate             0
# Transaction Amount    0
# Date                  0
# Merchant Name         0
# Category              0
# dtype: int64

# %% [markdown]
# ## Show The Heat Map Null Values Visualization

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.heatmap(df.isnull(), cbar = False)
# plt.show()

# %% [markdown]
# ## Drop the Null Values

# %%
df.dropna()
# Out:
#        customer_id       name    surname gender   birthdate  \
# 0           752858       Sean  Rodriguez      F  2002-10-20
# 2           305449      Jacob   Williams      M  1981-10-25
# 3           988259     Nathan     Snyder      M  1977-10-26
# 4           764762    Crystal      Knapp      F  1951-11-02
# 5           576539     Monica   Bartlett      F  2001-10-20
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  1997-10-21
# 49996       800560       Anna      Allen      F  1999-10-21
# 49997       133285     Nicole   Franklin      M  1979-10-26
# 49998       616122      Maria     Keller      M  1981-10-25
# 49999       832184      Billy     Walker      F  1958-10-31
#
#        transaction_amount        date                 merchant_name  \
# 0                   35.47  2023-04-03                 Smith-Russell
# 2                  115.97  2023-09-20                    Steele Inc
# ...

# %%
df.dropna(inplace = True)

# %%
df['Gender'].dropna()
# Out:
# 0        F
# 2        M
# 3        M
# 4        F
# 5        F
#         ..
# 49995    F
# 49996    F
# 49997    M
# 49998    M
# 49999    F
# Name: Gender, Length: 44953, dtype: object

# %% [markdown]
# ## Fill Null Values

# %%
df.fillna('MISSING')
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  2002-10-20
# 2           305449      Jacob   Williams      M  1981-10-25
# 3           988259     Nathan     Snyder      M  1977-10-26
# 4           764762    Crystal      Knapp      F  1951-11-02
# 5           576539     Monica   Bartlett      F  2001-10-20
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  1997-10-21
# 49996       800560       Anna      Allen      F  1999-10-21
# 49997       133285     Nicole   Franklin      M  1979-10-26
# 49998       616122      Maria     Keller      M  1981-10-25
# 49999       832184      Billy     Walker      F  1958-10-31
#
#        Transaction Amount        Date                 Merchant Name  \
# 0                   35.47  2023-04-03                 Smith-Russell
# 2                  115.97  2023-09-20                    Steele Inc
# ...

# %% [markdown]
# ## Show The Columns

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Name', 'Surname', 'Gender', 'Birthdate',
#        'Transaction Amount', 'Date', 'Merchant Name', 'Category'],
#       dtype='object')

# %% [markdown]
# ## Transaction Amount Boxplot Visualization

# %%
sns.boxplot(x = df['Transaction Amount'])
plt.show()

# %% [markdown]
# ## Show the Date Visualization

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.groupby('Date')['Transaction Amount'].sum().plot()
plt.show()

# %%
df = pd.read_csv("Transactions_dataset.csv")

# %%
import pandas as pd

df = pd.read_csv("Transactions_dataset.csv")

# %%
df.isnull().sum()
# Out:
# Customer ID              0
# Name                     0
# Surname                  0
# Gender                5047
# Birthdate                0
# Transaction Amount       0
# Date                     0
# Merchant Name            0
# Category                 0
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Customer ID            0.000
# Name                   0.000
# Surname                0.000
# Gender                10.094
# Birthdate              0.000
# Transaction Amount     0.000
# Date                   0.000
# Merchant Name          0.000
# Category               0.000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ## Outliers

# %%
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(df['Transaction Amount']))
outliers = df[z > 3]

print(outliers)
# Out:
#        Customer ID         Name    Surname Gender   Birthdate  \
# 1            26381     Michelle     Phelps    NaN  1985-10-24
# 39           11697        Jason    Johnson      F  2001-10-20
# 61          805732      Sabrina      White      F  1980-10-25
# 67           34415         Juan      Kelly      F  1995-10-22
# 96          981118      Anthony     Arnold      M  1971-10-28
# ...            ...          ...        ...    ...         ...
# 49869       388076         Paul      Ortiz      F  1964-10-29
# 49881       120060        Sarah       Pham      F  1967-10-29
# 49922       892727       Angela  Macdonald      M  1984-10-24
# 49926       958102        Brian     Bailey      M  1962-10-30
# 49931       167795  Christopher    Coleman      M  1980-10-25
#
#        Transaction Amount        Date              Merchant Name Category
# 1                 2552.72  2023-07-17     Peck, Spence and Young   Travel
# ...

# %%
Q1 = df['Transaction Amount'].quantile(0.25)
Q3 = df['Transaction Amount'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Transaction Amount'] < lower_bound) | (df['Transaction Amount'] > upper_bound)]

print(outliers)
# Out:
#        Customer ID      Name    Surname Gender   Birthdate  \
# 1            26381  Michelle     Phelps    NaN  1985-10-24
# 19          401993    Steven      Smith      M  1999-10-21
# 28          744599   William  Contreras      F  2003-10-20
# 33          485255       Amy     Mercer      F  1970-10-28
# 36          796123   Darlene     Tucker      M  1953-11-01
# ...            ...       ...        ...    ...         ...
# 49939       691543    Andrew   Griffith      F  1975-10-27
# 49956       751871   Jessica     Cooper      M  1972-10-27
# 49982       728409    Debbie    Griffin      M  1994-10-22
# 49983        91701    Joseph     Lawson      M  1985-10-24
# 49985       637225    Karina   Caldwell      F  1959-10-31
#
#        Transaction Amount        Date              Merchant Name Category
# 1                 2552.72  2023-07-17     Peck, Spence and Young   Travel
# 19                1468.14  2023-05-14  Thompson, Lopez and Mason   Travel
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID              0
# Name                     0
# Surname                  0
# Gender                5047
# Birthdate                0
# Transaction Amount       0
# Date                     0
# Merchant Name            0
# Category                 0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
import seaborn as sns
sns.boxplot(x=df['Transaction Amount'])
# Out:
# <Axes: xlabel='Transaction Amount'>

# %% [markdown]
# ## Find Quantile

# %%
Q1 = df['Transaction Amount'].quantile(0.25)
Q3 = df['Transaction Amount'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %% [markdown]
# ## Market Basket Analysis

# %%
[['Apple', 'Grapes', 'Mango'],
 ['Apple', 'Carrot'],
 ...]
# Out:
# [['Apple', 'Grapes', 'Mango'], ['Apple', 'Carrot'], Ellipsis]

# %%
import pandas as pd

df = pd.read_csv("Transactions_dataset.csv")

# %%
Transaction = [1,19,28,33,36]
Products = ['Apple','Banana','Carrot','Dragon fruit','Eggs']
print(Transaction)
print(Products)
# Out:
# [1, 19, 28, 33, 36]
# ['Apple', 'Banana', 'Carrot', 'Dragon fruit', 'Eggs']

# %%
df = df.dropna(subset=['Category'])

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# Customer ID             int64
# Name                   object
# Surname                object
# Gender                 object
# Birthdate              object
# Transaction Amount    float64
# Date                   object
# Merchant Name          object
# Category               object
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Transactions_dataset.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
products = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E', 
            'Product F', 'Product G', 'Product H', 'Product I', 'Product J']
counts = np.random.randint(10, 100, size=10)
product_counts = pd.Series(counts, index=products)

# %% [markdown]
# ## Show the Product Visualization

# %%
product_counts.plot(kind='bar')
plt.title('Top 10 Most Frequent Products')
plt.xlabel('Products')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
transactions = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread', 'Butter']
]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
rules = pd.DataFrame({
    'support': [0.1, 0.15, 0.2, 0.25, 0.3],
    'confidence': [0.5, 0.6, 0.7, 0.8, 0.9]
})

# %% [markdown]
# ## Scatter Plot Visualization

# %%
plt.scatter(rules['support'], rules['confidence'])
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.title('Association Rules')
plt.show()

# %%
df = pd.read_csv("Transactions_dataset.csv")

# %%
transactions = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread']
]

# %% [markdown]
# ## Install the Machinelearing

# %%
# !pip install mlxtend
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.4.4 which is incompatible.
# orange3 3.40.0 requires numpy<2.4,>=1.21.0, but you have numpy 2.4.4 which is incompatible.
# orange3 3.40.0 requires pandas<3,>=2.0.1, but you have pandas 3.0.2 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.8.0 which is incompatible.
# streamlit 1.45.1 requires pandas<3,>=1.4.0, but you have pandas 3.0.2 which is incompatible.
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.5 MB/s eta 0:00:00
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_data, columns=te.columns_)
print(df)
# Out:
#    Bread  Butter   Milk
# 0   True    True   True
# 1   True    True  False
# 2   True   False   True
# 3  False    True   True
# 4   True   False  False

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

print(frequent_itemsets)
# Out:
#    support         itemsets
# 0      0.8          (Bread)
# 1      0.6         (Butter)
# 2      0.6           (Milk)
# 3      0.4  (Butter, Bread)
# 4      0.4    (Bread, Milk)
# 5      0.4   (Butter, Milk)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print(rules)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0    (Butter)     (Bread)                 0.6                 0.8      0.4
# 1     (Bread)    (Butter)                 0.8                 0.6      0.4
# 2     (Bread)      (Milk)                 0.8                 0.6      0.4
# 3      (Milk)     (Bread)                 0.6                 0.8      0.4
# 4    (Butter)      (Milk)                 0.6                 0.6      0.4
# 5      (Milk)    (Butter)                 0.6                 0.6      0.4
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.666667  0.833333               1.0     -0.08         0.6
# 1    0.500000  0.833333               1.0     -0.08         0.8
# 2    0.500000  0.833333               1.0     -0.08         0.8
# 3    0.666667  0.833333               1.0     -0.08         0.6
# 4    0.666667  1.111111               1.0      0.04         1.2
# ...

# %%
strong_rules = rules[(rules['confidence'] > 0.6) & (rules['lift'] > 1)]
print(strong_rules)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 4    (Butter)      (Milk)                 0.6                 0.6      0.4
# 5      (Milk)    (Butter)                 0.6                 0.6      0.4
#
#    confidence      lift  representativity  leverage  conviction  \
# 4    0.666667  1.111111               1.0      0.04         1.2
# 5    0.666667  1.111111               1.0      0.04         1.2
#
#    zhangs_metric  jaccard  certainty  kulczynski
# 4           0.25      0.5   0.166667    0.666667
# 5           0.25      0.5   0.166667    0.666667

# %%
import matplotlib.pyplot as plt

# %%
frequent_itemsets.sort_values(by='support', ascending=False).head(10).plot(
    x='itemsets', y='support', kind='bar'
)
# Out:
# <Axes: xlabel='itemsets'>

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.scatter(rules['support'], rules['confidence'], s=rules['lift']*100)

plt.xlabel('Support')
plt.ylabel('Confidence')
plt.title('Support vs Confidence (Lift as size)')
plt.show()

# %% [markdown]
# ## Import Network

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.DiGraph()

for _, row in rules.iterrows():
    G.add_edge(str(row['antecedents']),
               str(row['consequents']),
               weight=row['lift'])

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=2000)

plt.title('Product Relationship Network')
plt.show()

# %%
plt.scatter(rules['support'], rules['confidence'],
            s=rules['lift']*100)

plt.xlabel('Support')
plt.ylabel('Confidence')
plt.title('Product Relationship Strength')
plt.show()

# %%
transactions = [
    ['Milk', 'Bread', 'Butter'],
    ['Bread', 'Butter'],
    ['Milk', 'Bread'],
    ['Milk', 'Butter'],
    ['Bread', 'Butter']
]

# %%
pip install mlxtend
# Out:
# ...
#
# ...

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_data, columns=te.columns_)
print(df)
# Out:
#    Bread  Butter   Milk
# 0   True    True   True
# 1   True    True  False
# 2   True   False   True
# 3  False    True   True
# 4   True    True  False

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print(frequent_itemsets)
# Out:
#    support         itemsets
# 0      0.8          (Bread)
# 1      0.8         (Butter)
# 2      0.6           (Milk)
# 3      0.6  (Butter, Bread)
# 4      0.4    (Bread, Milk)
# 5      0.4   (Butter, Milk)

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print(rules)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0    (Butter)     (Bread)                 0.8                 0.8      0.6
# 1     (Bread)    (Butter)                 0.8                 0.8      0.6
# 2      (Milk)     (Bread)                 0.6                 0.8      0.4
# 3      (Milk)    (Butter)                 0.6                 0.8      0.4
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.750000  0.937500               1.0     -0.04         0.8
# 1    0.750000  0.937500               1.0     -0.04         0.8
# 2    0.666667  0.833333               1.0     -0.08         0.6
# 3    0.666667  0.833333               1.0     -0.08         0.6
#
#    zhangs_metric  jaccard  certainty  kulczynski
# 0      -0.250000      0.6  -0.250000    0.750000
# 1      -0.250000      0.6  -0.250000    0.750000
# 2      -0.333333      0.4  -0.666667    0.583333
# 3      -0.333333      0.4  -0.666667    0.583333
